# %%
import pandas as pd
import json

# Sample JSON data
json_data = '''
[
    {
        "casper": {
            "casper_id": "2094119",
            "department": "YKB_Resort",
            "designation": "Supervisor",
            "id": 1,
            "name": "Rajat Kumar"
        },
        "date": "2024-05-31",
        "id": 4,
        "shift": "Morning",
        "station": {
            "id": 3,
            "station": "NZStation2",
            "type": "Secondary",
            "zone": "CBS"
        }
    },
    {
        "casper": {
            "casper_id": "2094119",
            "department": "YKB_Resort",
            "designation": "Supervisor",
            "id": 1,
            "name": "Rajat Kumar"
        },
        "date": "2024-05-31",
        "id": 5,
        "shift": "Night",
        "station": {
            "id": 3,
            "station": "NZStation2",
            "type": "Secondary",
            "zone": "CBS"
        }
    },
    {
        "casper": {
            "casper_id": "2102151",
            "department": "YKB_CBS",
            "designation": "Supervisor",
            "id": 2,
            "name": "NITISH KUMAR"
        },
        "date": "2024-05-31",
        "id": 6,
        "shift": "Night",
        "station": {
            "id": 3,
            "station": "NZStation2",
            "type": "Secondary",
            "zone": "CBS"
        }
    },
    {
        "casper": {
            "casper_id": "2137831",
            "department": "YKB_Resort",
            "designation": "DEO",
            "id": 5,
            "name": "Lakhan Yadav"
        },
        "date": "2024-05-31",
        "id": 7,
        "shift": "Night",
        "station": {
            "id": 2,
            "station": "NZStation1",
            "type": "Secondary",
            "zone": "CBS"
        }
    },
    {
        "casper": {
            "casper_id": "2112455",
            "department": "YKB_Resort",
            "designation": "DEO",
            "id": 3,
            "name": "Atul Kumar"
        },
        "date": "2024-05-31",
        "id": 8,
        "shift": "Night",
        "station": {
            "id": 2,
            "station": "NZStation1",
            "type": "Secondary",
            "zone": "CBS"
        }
    },
    {
        "casper": {
            "casper_id": "2160549",
            "department": "YKB_Resort",
            "designation": "DEO",
            "id": 9,
            "name": "Hariom Singh"
        },
        "date": "2024-05-31",
        "id": 9,
        "shift": "Morning",
        "station": {
            "id": 2,
            "station": "NZStation1",
            "type": "Secondary",
            "zone": "CBS"
        }
    },
    {
        "casper": {
            "casper_id": "2133239",
            "department": "YKB_CBS",
            "designation": "DEO (SME)",
            "id": 4,
            "name": "Khagesh Vashishath"
        },
        "date": "2024-05-31",
        "id": 10,
        "shift": "Morning",
        "station": {
            "id": 2,
            "station": "NZStation1",
            "type": "Secondary",
            "zone": "CBS"
        }
    },
    {
        "casper": {
            "casper_id": "2139446",
            "department": "YKB_Resort",
            "designation": "DEO",
            "id": 6,
            "name": "PRABHUNATH YADAV"
        },
        "date": "2024-05-31",
        "id": 11,
        "shift": "Morning",
        "station": {
            "id": 2,
            "station": "NZStation1",
            "type": "Secondary",
            "zone": "CBS"
        }
    },
    {
        "casper": {
            "casper_id": "2158116",
            "department": "YKB_Resort",
            "designation": "DEO",
            "id": 8,
            "name": "Parvinder"
        },
        "date": "2024-05-31",
        "id": 12,
        "shift": "Morning",
        "station": {
            "id": 2,
            "station": "NZStation1",
            "type": "Secondary",
            "zone": "CBS"
        }
    },
    {
        "casper": {
            "casper_id": "2163052",
            "department": "YKB_CBS",
            "designation": "DEO (SME)",
            "id": 10,
            "name": "Tarun Kumar"
        },
        "date": "2024-05-31",
        "id": 13,
        "shift": "Morning",
        "station": {
            "id": 2,
            "station": "NZStation1",
            "type": "Secondary",
            "zone": "CBS"
        }
    }
]
'''

# Load the JSON data
data = json.loads(json_data)
# Flatten the JSON data and convert it to a DataFrame
df = pd.json_normalize(data)

# Create a pivot table to count the number of individuals at each station
pivot_table = df.pivot_table(index='station.type', values='casper.name', aggfunc='count')
a = pivot_table.to_dict()

print(a)
# Out:
# {'casper.name': {'Secondary': 10}}
